# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamednishan224/ict_assignments/blob/main/assignment02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1


'''For a given range of numbers (e.g., 1 to 100), print "Fizz" if the number is
divisible by 3, "Buzz" if it's divisible by 5, and "FizzBuzz" if it's divisible by both. Otherwise,
print the number itself'''


num = int(input("Enter a number between 1 to 100:"))
for i in range(0,101):
   if num%3 == 0 and num%5 == 0:
     print("FizzBuzz")
     break
   elif num%3 == 0:
     print("Fizz")
     break
   elif num%5 == 0:
     print("Buzz")
     break
   else:
     print("Not divisible")
     break
# Out:
# Enter a number between 1 to 100:50
# Buzz

# %%
#2

units = int(input("Enter the units consumed:"))
if units <= 100:
  total_bill = units*5
  print(total_bill)
elif units <= 200 and units >=100:
  total_bill = (100*5)+((units-100)*7)
  print(total_bill)
elif units >200:
  total_bill = (100*5)+((units-100)*7)+((units-200)*10)
  print(total_bill)
else:
  print("Not available")
# Out:
# Enter the units consumed:50
# 250

# %%
#3

sym ='*'
for i in range(5):
    print(sym)
    sym = sym + '*'
# Out:
# *
# **
# ***
# ****
# *****

# %%
#4


pal = str(input("Enter a number or string:"))
rev_pal = pal[::-1]

if rev_pal == pal:
 print(pal,"is a palindrome")
else:
 print(pal,"is not a palindrome")
# Out:
# Enter a number or string:12
# 12 is not a palindrome
